# %% [markdown]
# # Python_Assignment_018

# %% [markdown]
# **Concepts used:-**
# Packages and modules
# collections module
# OrderedDict
# defaultdict
# Python interpreter

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ### 1. Create a zoo.py file first. Define the hours() function, which prints the string &#39;Open 9-5 daily&#39;. Then, use the interactive interpreter to import the zoo module and call its hours() function.

# %% [markdown]
# ### Steps to create packages and modules :-
# 1. Create a text file and write the functions and save it as zoo.py
# 2. Now import the package using filename without .py

# %%
import zoo

# %%
zoo.hours()
# Out:
# open 9-5 daily

# %% [markdown]
# ### You can check the output in the command prompt python interpreter.
#
# **method 1:-** Open command prompt and go to the location where your zoo.py file is present. Copy location from file manager
# ![image.png](attachment:image.png)
#
#
# **method 2:-** Go to the place where your file is present in file manager. Then remove the path at the top and type 'cmd' and press enter.
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Steps to follow:-
# **step 1:-** Follow method 1 or 2 then a command prompt will open. Type python to convert the command prompt into python interpreter.
# **Step 2:-**  Type import zoo   - package
# **step 3:-**  Type zoo.hours()  - package.function()
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ## 2. In the interactive interpreter, import the zoo module as menagerie and call its hours() function.

# %%
import zoo as menagerie   # we can keep alias names to modules
menagerie.hours()
# Out:
# open 9-5 daily

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ### 3. Using the interpreter, explicitly import and call the hours() function from zoo.

# %%
from zoo import hours  # we can directly call a function (or) module from a package
hours()
# Out:
# open 9-5 daily

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ### 4. Import the hours() function as info and call it.

# %%
from zoo import hours as info   # we can keep alias names to functions.
info()
# Out:
# open 9-5 daily

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ## 5. Create a plain dictionary with the key-value pairs &#39;a&#39;: 1, &#39;b&#39;: 2, and &#39;c&#39;: 3, and print it out.

# %%
plain = {'a':1, 'b':2, 'c':3}
plain
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ## 6.Make an OrderedDict called fancy from the same pairs listed in 5 and print it. Did it print in the same order as plain?

# %%
from collections import OrderedDict

fancy = OrderedDict(plain)

print(fancy)
# Out:
# OrderedDict([('a', 1), ('b', 2), ('c', 3)])

# %% [markdown]
# ==============================================================================================================

# %% [markdown]
# ### 7. Make a default dictionary called dict_of_lists and pass it the argument list. Make the list dict_of_lists[&#39;a&#39;] and append the value &#39;something for a&#39; to it in one assignment. Print dict_of_lists[&#39;a&#39;].

# %%
from collections import defaultdict

dict_of_lists  = defaultdict(list)
dict_of_lists['a'].append('something for a')
dict_of_lists
# Out:
# defaultdict(list, {'a': ['something for a']})

# %% [markdown]
# ==============================================================================================================
